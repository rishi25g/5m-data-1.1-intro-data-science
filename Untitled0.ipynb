# %% [markdown]
# <a href="https://colab.research.google.com/github/rishi25g/5m-data-1.1-intro-data-science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
# Out:
# Hello, GitHub! This is my first commit.
